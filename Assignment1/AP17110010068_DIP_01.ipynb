# %% [markdown]
# # DIP Lab Assignment 01

# %%
# importing OpenCV(cv2) & matplotlib module
import cv2
import matplotlib.pyplot as plt

# %%
#Loading Image
img = cv2.imread('lena_color.tiff')

# %%
plt.imshow(img, cmap=plt.cm.bone)
plt.show()

# %%
import matplotlib.image as mpimg

# %%
imgm = mpimg.imread('lena_color.tiff')

# %%
plt.imshow(img, cmap=plt.cm.bone)
plt.show()
